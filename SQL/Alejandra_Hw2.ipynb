# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleja-Cardenas/Micro-credentials-/blob/main/SQL/Alejandra_Hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Alejandra Cardenas Garces
# ## Lesson 5: Join and Unions
#
# 1. Join the film to the film actor table
#
# # ![Screen Shot 2022-08-13 at 8.00.19 AM.png](data:image/png;base64,...)

# %% [markdown]
# 2. Join the actor table to the film actor table
#
# ![Screen Shot 2022-08-13 at 8.22.07 AM.png](data:image/png;base64,...)

# %% [markdown]
# 3. Try to join the actor, film_actor and film table togheter (3 joins!)
#
# ![Screen Shot 2022-08-13 at 8.32.03 AM.png](data:image/png;base64,...)
