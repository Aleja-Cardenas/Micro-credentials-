# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleja-Cardenas/Micro-credentials-/blob/main/SQL/Alejandra_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Alejandra Cardenas
# ## Lesson 9: Insert and Update
#
# 1. **Create** a table with the following parameters:
#
# *   CustomerID
# *   CustomerName
# *   Address
# *   City
# *   PostalCode
# *   Country
# *   Email
#
# 2. Insert 3 rows of data into these columns **INSERT**. The data you insert should make sense for the column.
#
# **Solution 1&2 **
#
# ![Screen Shot 2022-08-14 at 9.35.03 PM.png](data:image/png;base64,...)

# %% [markdown]
# 3. Use an **UPDATE** to modify any portion of the data
# ![Screen Shot 2022-08-14 at 9.48.43 PM.png](data:image/png;base64,...)

# %% [markdown]
# 4. Finallu write a statement to **delete **one row data.
# ![Screen Shot 2022-08-14 at 9.54.21 PM.png](data:image/png;base64,...)
